# %%
# Criando gráficos

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('desafios-propostos/kpop_data.csv')
#df = df.drop(df.columns[0], axis = 1)
df.head()
# Out:
#       Name  DebutYear  AnnualSales      TopSong  YouTubeMetrics  Awards  \
# 0      BTS       2013     20000000     Dynamite      1200000000     300
# 1      EXO       2012     10000000        Growl       250000000     100
# 2     GOT7       2012      5000000   Just Right       350000000      70
# 3  MAMAMOO       2014      4000000          HIP       150000000      60
# 4      NCT       2016      7000000  Cherry Bomb       100000000      90
#
#    Members                Company  Albums Active
# 0        7  Big Hit Entertainment       9    Yes
# 1        9       SM Entertainment       6    Yes
# 2        7      JYP Entertainment       5     No
# 3        4                    RBW       3    Yes
# 4       23       SM Entertainment       4    Yes

# %%
eixo_x = df["Active"].value_counts().sort_index().keys()
eixo_y = df["Active"].value_counts().sort_index().values

plt.title("Qtd de grupos ativos")
plt.xlabel("Status")
plt.ylabel("Qtd de grupos ativos")

plt.plot(eixo_x, eixo_y)

# %%
eixo_x = df['DebutYear'].value_counts().keys()
eixo_y = df['DebutYear'].value_counts().values

plt.title("Qtd de Debuts por ano")
plt.xlabel("Ano")
plt.ylabel("Qtd de Debuts")

plt.bar(eixo_x, eixo_y)
plt.show()
