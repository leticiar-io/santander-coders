# %%
# Tratando dados

import pandas as pd

# %%
df = pd.read_csv("kpop_data_nao_tratado.csv")
df
# Out:
#           Name  DebutYear  AnnualSales          TopSong   YouTubeMetrics  \
# 0          BTS       2013   20000000.0         Dynamite       1200000000
# 1          EXO       2012   10000000.0            Growl        250000000
# 2         GOT7       2012    5000000.0       Just Right        350000000
# 3      MAMAMOO       2014    4000000.0              HIP        150000000
# 4          NCT       2016    7000000.0      Cherry Bomb  100000000 views
# 5    Seventeen       2012    6000000.0  Don't Wanna Cry        180000000
# 6     Monsta X       2015    3000000.0        Shoot Out         90000000
# 7          AOA       2012    2000000.0       Like a Cat         50000000
# 8   Crayon Pop       2012    1500000.0      Bar Bar Bar         70000000
# 9         VIXX       2012    3000000.0      Voodoo Doll         90000000
# 10       TWICE       2015    8000000.0         Cheer Up        450000000
#
#     Awards  Members                  Company  Albums Active
# ...

# %%
auxiliar = df.loc[4]

# %%
def limpa_preco(linha):
   linha['YouTubeMetrics'] = linha['YouTubeMetrics'].replace(' views', '')
   return linha

df.apply(lambda x: limpa_preco(x), axis=1)
# Out:
#           Name  DebutYear  AnnualSales          TopSong YouTubeMetrics  \
# 0          BTS       2013   20000000.0         Dynamite     1200000000
# 1          EXO       2012   10000000.0            Growl      250000000
# 2         GOT7       2012    5000000.0       Just Right      350000000
# 3      MAMAMOO       2014    4000000.0              HIP      150000000
# 4          NCT       2016    7000000.0      Cherry Bomb      100000000
# 5    Seventeen       2012    6000000.0  Don't Wanna Cry      180000000
# 6     Monsta X       2015    3000000.0        Shoot Out       90000000
# 7          AOA       2012    2000000.0       Like a Cat       50000000
# 8   Crayon Pop       2012    1500000.0      Bar Bar Bar       70000000
# 9         VIXX       2012    3000000.0      Voodoo Doll       90000000
# 10       TWICE       2015    8000000.0         Cheer Up      450000000
#
#     Awards  Members                  Company  Albums Active
# ...
